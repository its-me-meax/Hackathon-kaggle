# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df_Test=pd.read_csv("test.csv")
df_Train=pd.read_csv("train.csv")

# %%
df_Test.head()
# Out:
#       id PROJECTNUMBER  MW   PROJECT_CITY           STATE PROJECT_COUNTRY  \
# 0   3708       A0-0068 NaN  Visakhapatnam  Andhra Pradesh           India
# 1   6302       A0-0162 NaN        Lucknow   Uttar Pradesh           India
# 2   8687       A0-0219 NaN         Indore  Madhya Pradesh           India
# 3    361       A0-0005 NaN       Warangal       Telangana           India
# 4  13231       A0-0023 NaN        Kolkata     West Bengal           India
#
#       CORE_MARKET          PROJECT_TYPE  SIZE_BUILDINGSIZE  NUMFLOORS  ...  \
# 0      Enterprise          Critical Ops           265850.0        0.0  ...
# 1  Bio Innovation  R&amp;D Laboratories           288000.0        0.0  ...
# 2     Misc Market          Learning Hub            40000.0        2.0  ...
# 3     Misc Market          Learning Hub            36700.0        4.0  ...
# 4      Enterprise      Hospitality Hall           435000.0       11.0  ...
#
# ...

# %%
df_Test.join(df_Train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_Test.join(df_Train)
#
# File c:\Users\ultra\Desktop\bootcamp\pythonn\venvv\Lib\site-packages\pandas\core\frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)  10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
#   10764         suffixes=(lsuffix, rsuffix),
#   10765         sort=sort,
#   10766         validate=validate,
#   10767     )
#   10768 else:
#   10769     if on is not None:
#
# ...

# %%
df=df_Train.merge(df_Test)

# %%
df_Train
# Out:
#           id PROJECTNUMBER    MW PROJECT_CITY        STATE PROJECT_COUNTRY  \
# 0       3478       A0-0070   NaN       Mumbai  Maharashtra           India
# 1       8006       A0-0208   NaN        Delhi        Delhi           India
# 2       5748       A0-0004   NaN    Bengaluru    Karnataka           India
# 3       7898       A0-0166   NaN      Chennai   Tamil Nadu           India
# 4      11030       A0-0242   NaN    Hyderabad    Telangana           India
# ...      ...           ...   ...          ...          ...             ...
# 14031  16717       A0-0548  10.0      Kolkata  West Bengal           India
# 14032  16718       A0-0548  10.0      Kolkata  West Bengal           India
# 14033  16719       A0-0548  10.0      Kolkata  West Bengal           India
# 14034  16720       A0-0548  10.0      Kolkata  West Bengal           India
# 14035  16721       A0-0548  10.0      Kolkata  West Bengal           India
#
# ...

# %%
df_Test
# Out:
#          id PROJECTNUMBER  MW   PROJECT_CITY           STATE PROJECT_COUNTRY  \
# 0      3708       A0-0068 NaN  Visakhapatnam  Andhra Pradesh           India
# 1      6302       A0-0162 NaN        Lucknow   Uttar Pradesh           India
# 2      8687       A0-0219 NaN         Indore  Madhya Pradesh           India
# 3       361       A0-0005 NaN       Warangal       Telangana           India
# 4     13231       A0-0023 NaN        Kolkata     West Bengal           India
# ...     ...           ...  ..            ...             ...             ...
# 2680   4897       A0-0153 NaN            NaN     West Bengal           India
# 2681   2821       A0-0064 NaN          Patna           Bihar           India
# 2682  11365       A0-0023 NaN        Kolkata     West Bengal           India
# 2683   9924       A0-0161 NaN     Coimbatore      Tamil Nadu           India
# 2684  10410       A0-0186 NaN           Pune     Maharashtra           India
#
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: [id, PROJECTNUMBER, MW, PROJECT_CITY, STATE, PROJECT_COUNTRY, CORE_MARKET, PROJECT_TYPE, SIZE_BUILDINGSIZE, NUMFLOORS, NUMROOMS, NUMBEDS, invoiceId, invoiceDate, invoiceTotal, ItemDescription, MasterItemNo, QtyShipped, UOM, ExtendedQuantity, PriceUOM, UnitPrice, ExtendedPrice, CONSTRUCTION_START_DATE, SUBSTANTIAL_COMPLETION_DATE, REVISED_ESTIMATE]
# Index: []
#
# [0 rows x 26 columns]

# %%
df_Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2685 entries, 0 to 2684
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           2685 non-null   int64
#  1   PROJECTNUMBER                2685 non-null   object
#  2   MW                           0 non-null      float64
#  3   PROJECT_CITY                 2680 non-null   object
#  4   STATE                        2685 non-null   object
#  5   PROJECT_COUNTRY              2685 non-null   object
#  6   CORE_MARKET                  2685 non-null   object
#  7   PROJECT_TYPE                 2685 non-null   object
#  8   SIZE_BUILDINGSIZE            2678 non-null   float64
#  9   NUMFLOORS                    1849 non-null   float64
#  10  NUMROOMS                     1393 non-null   float64
#  11  NUMBEDS                      1200 non-null   float64
#  12  invoiceId                    2685 non-null   object
# ...

# %%
df_Train['CORE_MARKET'].unique()
# Out:
# array(['Enterprise', 'Wellness', 'Tertiary Learning', 'Misc Market',
#        'Future Tech', 'Bio Innovation'], dtype=object)

# %%
df_Train[df_Train['PROJECT_TYPE'].isnull()]
# Out:
#         id PROJECTNUMBER  MW PROJECT_CITY      STATE PROJECT_COUNTRY  \
# 566   4618       A0-0122 NaN       Ranchi  Jharkhand           India
# 8381  4617       A0-0122 NaN       Ranchi  Jharkhand           India
#
#             CORE_MARKET PROJECT_TYPE  SIZE_BUILDINGSIZE  NUMFLOORS  ...  \
# 566   Tertiary Learning          NaN                0.0        NaN  ...
# 8381  Tertiary Learning          NaN                0.0        NaN  ...
#
#       MasterItemNo  QtyShipped  UOM ExtendedQuantity  PriceUOM UnitPrice  \
# 566          58170           1  NaN              NaN       NaN  27367.96
# 8381         58170           1  NaN              NaN       NaN  27367.96
#
#      ExtendedPrice CONSTRUCTION_START_DATE SUBSTANTIAL_COMPLETION_DATE  \
# 566            NaN          7/18/2022 0:00              1/31/2024 0:00
# 8381           NaN          7/18/2022 0:00              1/31/2024 0:00
#
#      REVISED_ESTIMATE
# 566        40698985.5
# 8381       40698985.5
#
# [2 rows x 26 columns]

# %%
df_Trai

# %%
df_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14036 entries, 0 to 14035
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           14036 non-null  int64
#  1   PROJECTNUMBER                14036 non-null  object
#  2   MW                           3300 non-null   float64
#  3   PROJECT_CITY                 14036 non-null  object
#  4   STATE                        14036 non-null  object
#  5   PROJECT_COUNTRY              14036 non-null  object
#  6   CORE_MARKET                  14036 non-null  object
#  7   PROJECT_TYPE                 14034 non-null  object
#  8   SIZE_BUILDINGSIZE            14006 non-null  float64
#  9   NUMFLOORS                    9587 non-null   float64
#  10  NUMROOMS                     6744 non-null   float64
#  11  NUMBEDS                      5909 non-null   float64
# ...

# %%
df_Train.isnull().sum()
# Out:
# id                                 0
# PROJECTNUMBER                      0
# MW                             10736
# PROJECT_CITY                       0
# STATE                              0
# PROJECT_COUNTRY                    0
# CORE_MARKET                        0
# PROJECT_TYPE                       2
# SIZE_BUILDINGSIZE                 30
# NUMFLOORS                       4449
# NUMROOMS                        7292
# NUMBEDS                         8127
# invoiceId                          0
# invoiceDate                        0
# invoiceTotal                     265
# ItemDescription                    0
# MasterItemNo                       0
# QtyShipped                        35
# UOM                             1647
# ExtendedQuantity                1867
# PriceUOM                        3957
# UnitPrice                         13
# ExtendedPrice                   2522
# CONSTRUCTION_START_DATE            0
# SUBSTANTIAL_COMPLETION_DATE        0
# ...

# %%
df_Train['PROJECT_CITY'].value_counts()
# Out:
# PROJECT_CITY
# Kolkata               2103
# Ahmedabad             1590
# Tiruchirappalli       1151
# Jaipur                 896
# Mumbai                 877
# Bengaluru              725
# Chennai                510
# Varanasi               481
# Pune                   395
# Vadodara               330
# Rajkot                 298
# Warangal               270
# Lucknow                269
# Nagpur                 232
# Guwahati               231
# Indore                 229
# Patna                  221
# Chandigarh             215
# Cuttack                207
# Visakhapatnam          206
# Ranchi                 205
# Dehradun               194
# Kochi                  168
# Coimbatore             166
# Thiruvananthapuram     148
# Meerut                 137
# Surat                  127
# Gwalior                123
# Aurangabad             119
# Madurai                 90
# Kolhapur                77
# Haridwar                75
# Amritsar                74
# ...

# %%
df['PROJECT_CITY'] = df['PROJECT_CITY'].str.strip().str.title()
print(df['PROJECT_CITY'].value_counts())
# Out:
# Series([], Name: count, dtype: int64)

# %%
city_corrections = {
    "Allahabad": "Prayagraj",
    "Hubli": "Hubballi",
    "Bangalore": "Bengaluru",
    "Mysore": "Mysuru",
    "Trivandrum": "Thiruvananthapuram",
    "Calcutta": "Kolkata"
}
df['PROJECT_CITY'] = df['PROJECT_CITY'].replace(city_corrections)

# %%
df_Train['PROJECT_COUNTRY'].value_counts()
# Out:
# PROJECT_COUNTRY
# India    14036
# Name: count, dtype: int64

# %%
## Check Misssing Values
##these are the features with nan value
features_with_na=[features for features in df_Train.columns if df_Train[features].isnull().sum()>=1]
for feature in features_with_na:
    print(feature,np.round(df_Train[feature].isnull().mean()*100,5), '% missing values')
# Out:
# MW 76.48903 % missing values
# PROJECT_TYPE 0.01425 % missing values
# SIZE_BUILDINGSIZE 0.21374 % missing values
# NUMFLOORS 31.69706 % missing values
# NUMROOMS 51.95212 % missing values
# NUMBEDS 57.90111 % missing values
# invoiceTotal 1.888 % missing values
# QtyShipped 0.24936 % missing values
# UOM 11.73411 % missing values
# ExtendedQuantity 13.30151 % missing values
# PriceUOM 28.19179 % missing values
# UnitPrice 0.09262 % missing values
# ExtendedPrice 17.96808 % missing values

# %%
# Check correlations of numeric columns to target
numeric_cols = df_Train.select_dtypes(include='number').columns
df_Train[numeric_cols].corr()['QtyShipped'].sort_values(ascending=False)
# Out:
# QtyShipped           1.000000
# NUMBEDS              0.205575
# id                   0.199806
# invoiceTotal         0.175842
# MW                   0.102491
# NUMFLOORS            0.062527
# ExtendedPrice        0.060511
# REVISED_ESTIMATE     0.038658
# SIZE_BUILDINGSIZE   -0.007778
# UnitPrice           -0.010416
# NUMROOMS            -0.050392
# Name: QtyShipped, dtype: float64

# %%
df_Train.head()
# Out:
#       id PROJECTNUMBER  MW PROJECT_CITY        STATE PROJECT_COUNTRY  \
# 0   3478       A0-0070 NaN       Mumbai  Maharashtra           India
# 1   8006       A0-0208 NaN        Delhi        Delhi           India
# 2   5748       A0-0004 NaN    Bengaluru    Karnataka           India
# 3   7898       A0-0166 NaN      Chennai   Tamil Nadu           India
# 4  11030       A0-0242 NaN    Hyderabad    Telangana           India
#
#          CORE_MARKET     PROJECT_TYPE  SIZE_BUILDINGSIZE  NUMFLOORS  ...  \
# 0         Enterprise        Workspace             9000.0        0.0  ...
# 1           Wellness    Health Center            31200.0        NaN  ...
# 2         Enterprise        Workspace          2800000.0        0.0  ...
# 3  Tertiary Learning     Learning Hub           184000.0        0.0  ...
# 4           Wellness  Ambulatory Care            25000.0        NaN  ...
#
#    MasterItemNo  QtyShipped  UOM ExtendedQuantity  PriceUOM  UnitPrice  \
# ...

# %%
df_Train.select_dtypes(include='number').corr()["QtyShipped"]
# Out:
# id                   0.199806
# MW                   0.102491
# SIZE_BUILDINGSIZE   -0.007778
# NUMFLOORS            0.062527
# NUMROOMS            -0.050392
# NUMBEDS              0.205575
# invoiceTotal         0.175842
# QtyShipped           1.000000
# UnitPrice           -0.010416
# ExtendedPrice        0.060511
# REVISED_ESTIMATE     0.038658
# Name: QtyShipped, dtype: float64

# %%
print(df_Train.columns.tolist())
# Out:
# ['id', 'PROJECTNUMBER', 'MW', 'PROJECT_CITY', 'STATE', 'PROJECT_COUNTRY', 'CORE_MARKET', 'PROJECT_TYPE', 'SIZE_BUILDINGSIZE', 'NUMFLOORS', 'NUMROOMS', 'NUMBEDS', 'invoiceId', 'invoiceDate', 'invoiceTotal', 'ItemDescription', 'MasterItemNo', 'QtyShipped', 'UOM', 'ExtendedQuantity', 'PriceUOM', 'UnitPrice', 'ExtendedPrice', 'CONSTRUCTION_START_DATE', 'SUBSTANTIAL_COMPLETION_DATE', 'REVISED_ESTIMATE']

# %%
print(df_Train['QtyShipped'].dtype)
# Out:
# float64

# %%
df_Train['QtyShipped'] = pd.to_numeric(df_Train['QtyShipped'], errors='coerce')

# %%
df_Train=df_Train.drop(columns=["MW","id","SIZE_BUILDINGSIZE","UnitPrice","NUMROOMS","REVISED_ESTIMATE"],axis=1)

# %%
df_Train.isnull().sum()
# Out:
# PROJECTNUMBER                     0
# PROJECT_CITY                      0
# STATE                             0
# PROJECT_COUNTRY                   0
# CORE_MARKET                       0
# PROJECT_TYPE                      2
# NUMFLOORS                      4449
# NUMBEDS                        8127
# invoiceId                         0
# invoiceDate                       0
# invoiceTotal                    265
# ItemDescription                   0
# MasterItemNo                      0
# QtyShipped                       89
# UOM                            1647
# ExtendedQuantity               1867
# PriceUOM                       3957
# ExtendedPrice                  2522
# CONSTRUCTION_START_DATE           0
# SUBSTANTIAL_COMPLETION_DATE       0
# dtype: int64

# %%
df=df_Train.dropna(subset=['QtyShipped'])

# %%
df.isnull().sum()
# Out:
# PROJECTNUMBER                     0
# PROJECT_CITY                      0
# STATE                             0
# PROJECT_COUNTRY                   0
# CORE_MARKET                       0
# PROJECT_TYPE                      2
# NUMFLOORS                      4430
# NUMBEDS                        8061
# invoiceId                         0
# invoiceDate                       0
# invoiceTotal                    264
# ItemDescription                   0
# MasterItemNo                      0
# QtyShipped                        0
# UOM                            1606
# ExtendedQuantity               1827
# PriceUOM                       3915
# ExtendedPrice                  2505
# CONSTRUCTION_START_DATE           0
# SUBSTANTIAL_COMPLETION_DATE       0
# dtype: int64

# %%
df=df_Train.dropna(subset=['invoiceTotal'])

# %%
df
# Out:
#       PROJECTNUMBER PROJECT_CITY        STATE PROJECT_COUNTRY  \
# 0           A0-0070       Mumbai  Maharashtra           India
# 1           A0-0208        Delhi        Delhi           India
# 2           A0-0004    Bengaluru    Karnataka           India
# 3           A0-0166      Chennai   Tamil Nadu           India
# 4           A0-0242    Hyderabad    Telangana           India
# ...             ...          ...          ...             ...
# 14031       A0-0548      Kolkata  West Bengal           India
# 14032       A0-0548      Kolkata  West Bengal           India
# 14033       A0-0548      Kolkata  West Bengal           India
# 14034       A0-0548      Kolkata  West Bengal           India
# 14035       A0-0548      Kolkata  West Bengal           India
#
#              CORE_MARKET     PROJECT_TYPE  NUMFLOORS  NUMBEDS       invoiceId  \
# 0             Enterprise        Workspace        0.0      0.0         B0-0454
# ...

# %%
## Check Misssing Values
##these are the features with nan value
features_with_na=[features for features in df.columns if df[features].isnull().sum()>=1]
for feature in features_with_na:
    print(feature,np.round(df[feature].isnull().mean()*100,5), '% missing values')
# Out:
# PROJECT_TYPE 0.01434 % missing values
# NUMFLOORS 31.7631 % missing values
# NUMBEDS 57.79738 % missing values
# invoiceTotal 1.89288 % missing values
# UOM 11.51502 % missing values
# ExtendedQuantity 13.09959 % missing values
# PriceUOM 28.07055 % missing values
# ExtendedPrice 17.96085 % missing values

# %%
df.isnull().sum()
# Out:
# PROJECTNUMBER                     0
# PROJECT_CITY                      0
# STATE                             0
# PROJECT_COUNTRY                   0
# CORE_MARKET                       0
# PROJECT_TYPE                      2
# NUMFLOORS                      4430
# NUMBEDS                        8061
# invoiceId                         0
# invoiceDate                       0
# invoiceTotal                    264
# ItemDescription                   0
# MasterItemNo                      0
# QtyShipped                        0
# UOM                            1606
# ExtendedQuantity               1827
# PriceUOM                       3915
# ExtendedPrice                  2505
# CONSTRUCTION_START_DATE           0
# SUBSTANTIAL_COMPLETION_DATE       0
# dtype: int64

# %%
## filling with Median :->
df.NUMFLOORS.fillna(df.NUMFLOORS.median(), inplace=True)
df.NUMBEDS.fillna(df.NUMBEDS.median(), inplace=True)
df.ExtendedQuantity.fillna(df.ExtendedQuantity.median(), inplace=True)
df.invoiceTotal.fillna(df.invoiceTotal.median(), inplace=True)

#3 filling with mode :-> 
df.PriceUOM.fillna(df.PriceUOM.mode()[0], inplace=True)
df.UOM.fillna(df.UOM.mode()[0], inplace=True)
df.PROJECT_TYPE.fillna(df.PROJECT_TYPE.mode()[0], inplace=True)




## Extended Price :-> 
df['ExtendedPrice'].fillna(0, inplace=True)  # or recompute if formula available


#Age
df_Train.NUMFLOORS.fillna(df_Train.NUMFLOORS.median(), inplace=True)
df_Train.NUMBEDS.fillna(df_Train.NUMBEDS.median(), inplace=True)

#TypeofContract
df_Train..fillna(df_Train.TypeofContact.mode()[0], inplace=True)

#DurationOfPitch
df_Train.DurationOfPitch.fillna(df_Train.DurationOfPitch.median(), inplace=True)

#NumberOfFollowups
df_Train.NumberOfFollowups.fillna(df_Train.NumberOfFollowups.mode()[0], inplace=True)

#PreferredPropertyStar
df_Train.PreferredPropertyStar.fillna(df_Train.PreferredPropertyStar.mode()[0], inplace=True)

#NumberOfTrips
df_Train.NumberOfTrips.fillna(df_Train.NumberOfTrips.median(), inplace=True)

#NumberOfChildrenVisiting
df_Train.NumberOfChildrenVisiting.fillna(df_Train.NumberOfChildrenVisiting.mode()[0], inplace=True)

#MonthlyIncome
df_Train.MonthlyIncome.fillna(df_Train.MonthlyIncome.median(), inplace=True)
# DurationOfPitch:-> 
df.DurationOfPitch.fillna(df.DurationOfPitch.median(), inplace=True)

#NumberOfFollowups
df.NumberOfFollowups.fillna(df.NumberOfFollowups.mode()[0], inplace=True)

#PreferredPropertyStar
df.PreferredPropertyStar.fillna(df.PreferredPropertyStar.mode()[0], inplace=True)

#NumberOfTrips
df.NumberOfTrips.fillna(df.NumberOfTrips.median(), inplace=True)

#NumberOfChildrenVisiting
df.NumberOfChildrenVisiting.fillna(df.NumberOfChildrenVisiting.mode()[0], inplace=True)

#MonthlyIncome
df.MonthlyIncome.fillna(df.MonthlyIncome.median(), inplace=True)
